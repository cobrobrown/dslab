# %%
import pandas as pd

# %%
# CDC PLACES dataset, zip code
# https://chronicdata.cdc.gov/500-Cities-Places/PLACES-ZCTA-Data-GIS-Friendly-Format-2020-release/kee5-23sr
api = "https://chronicdata.cdc.gov/resource/kee5-23sr.json"
file = "PLACES__ZCTA_Data__GIS_Friendly_Format___2020_release.csv"

# %%
#df = pd.read_json(api)
df = pd.read_csv(file)
df.shape
# Out:
# (32409, 59)

# %%
df.head()
# Out:
#    ZCTA5  TotalPopulation  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 0   1086              687                6.9      ( 5.4,  7.8)
# 1   4469             2702               15.8      (10.6, 21.8)
# 2   6269             9844               11.1      ( 8.9, 13.6)
# 3   8240             2371               10.0      ( 8.4, 12.3)
# 4  11549             2922               10.2      ( 6.6, 15.1)
#
#    ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev BINGE_Crude95CI  \
# 0                  3.9        ( 3.4,  4.6)             36.4    (33.0, 39.9)
# 1                  6.8        ( 5.5,  7.9)             23.7    (20.7, 26.7)
# 2                  5.5        ( 4.9,  6.1)             20.9    (18.6, 23.3)
# 3                  3.1        ( 2.6,  3.5)             27.7    (24.8, 30.8)
# 4                  2.7        ( 2.1,  3.2)             26.6    (24.5, 28.7)
#
#    BPHIGH_CrudePrev BPHIGH_Crude95CI  ...  OBESITY_Crude95CI PHLTH_CrudePrev  \
# ...
